# %%
#SciKit Learn Series

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:/Users/Valued Customer/Desktop/SEDM-II/SEDM/iPython/SEDM-Manual-Data1.csv")

# %%
#https://plot.ly/python/ipython-notebook-tutorial/
from IPython.display import YouTubeVideo

# %%
YouTubeVideo("elojMnjn4kk")

# %%
YouTubeVideo("IsXXlYVBt1M")

# %%
YouTubeVideo("hd1W4CyPX58")

# %%
#Making predictions with scikit-learn
YouTubeVideo("RlQuVL6-qe8")

# %%
#Comparing machine learning models in scikit-learn
YouTubeVideo("0pP4EwWJgIU")

# %%
YouTubeVideo("3ZWuPVWq7p4")

# %%
YouTubeVideo("6dbrR-WymjI")

# %%
YouTubeVideo("Gol_qOgRqfA")

# %%
YouTubeVideo("85dtiMz9tSo")

# %%
YouTubeVideo("ZiKMIuYidY0")

# %%
YouTubeVideo("HC0J_SPm9co")

# %%
YouTubeVideo("KTeVOb8gaD4")

# %%
YouTubeVideo("y3ZTKFZ-1QQ")

# %%
YouTubeVideo("BJ5ARpYYI-c")

# %%
YouTubeVideo("URTZ2jKCgBc")

# %%
YouTubeVideo("7gAZoK6kGhM")

# %%
YouTubeVideo("80fZrVMurPM")

# %%
YouTubeVideo("L7R4HUQ-eQ0")

# %%
YouTubeVideo("9fOWryQq9J8")

# %%
YouTubeVideo("HjAB45qsx_c")

# %%
YouTubeVideo("MDP9FfsNx60")

# %%
MDP9FfsNx60

# %%
YouTubeVideo("elojMnjn4kk")

# %%
YouTubeVideo("elojMnjn4kk")

# %%
YouTubeVideo("elojMnjn4kk")

# %%
YouTubeVideo("elojMnjn4kk")

# %%
YouTubeVideo("elojMnjn4kk")
