# %% [markdown]
# ###https://chrisalbon.com/python/pandas_dataframe_load_xls.html

# %%
import pandas as pd
import ipywidgets as widgets
# %load_ext autoreload
import xlrd

# %%
scope = pd.ExcelFile('VSSR.xlsx')
scope

# %%
scope.sheet_names
# Out:
# ['Master', 'Sheet2', 'Sheet3']

# %%
df = scope.parse('Master')
df
# Out:
#              State                                         Registered  \
# 0          Alabama                                                Yes
# 1           Alaska                                                Yes
# 2          Arizona                                     Cant find site
# 3         Arkansas                                                 No
# 4       California                                                Yes
# 5         Colorado                                                Yes
# 6      Connecticut                        Waiting on validation email
# 7         Delaware  Sending to notification services not vendor re...
# 8          Florida                                                Yes
# 9          Georgia                            Do not know where to go
# 10          Hawaii                                       Must Pay $12
# 11           Idaho                                                Yes
# 12        Illinois                                           Must pay
# 13         Indiana              No: Need to hire a registered agent\n
# 14            Iowa                                                Yes
# 15          Kansas                                          cant find
# 16        Kentucky                                                Yes
# 17       Louisiana                                                NaN
# 18           Maine                           waiting on confirm email
# 19        Maryland                                                Yes
# 20   Massachusetts                            Do not know where to go
# 21        Michigan                                                Yes
# 22       Minnesota                                                Yes
# 23     Mississippi  https://www.ms.gov/dfa/contract_bid_search/Hom...
# 24        Missouri  https://self-service.stlouisco.com/MSS/Vendors...
# 25         Montana                                          Cant find
# 26        Nebraska                              sent email requesting
# 27          Nevada                                                Yes
# 28   New Hampshire                             Submitted for approval
# 29      New Jersey                            Do not know where to go
# 30      New Mexico                                                NaN
# 31        New York                            Do not know where to go
# 32  North Carolina                            Do not know where to go
# 33    North Dakota                            Do not know where to go
# 34            Ohio                                                NaN
# 35        Oklahoma                                                NaN
# 36          Oregon                                                NaN
# 37    Pennsylvania                                                Yes
# 38    Rhode Island                                                NaN
# 39  South Carolina                                                NaN
# 40    South Dakota                            Do not know where to go
# 41       Tennessee                                     Must submit W9
# 42           Texas                                                NaN
# 43            Utah                                                NaN
# 44         Vermont                                                NaN
# 45        Virginia                                                NaN
# 46      Washington                                                NaN
# 47   West Virginia                                                NaN
# 48       Wisconsin                                                NaN
# 49         Wyoming                                                NaN
#
#                                             I9_Issued  \
# 0                                                 Yes
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                Yes
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                    St Lewis County
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31        http://www.sfs.ny.gov/index.php/contact-sfs
# 32  https://ncwak-vss.hostams.com/webapp/PRDVSS1X1...
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                https://bfm.sd.gov/vendor/index.asp
# 41  https://www.tn.gov/generalservices/topic/vendo...
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                           Vendor_Code                   id  \
# 0                                         VS000026207           jeffgrover
# 1                                            VS005092           jeffgrover
# 2                  Sent email screenshot for response  vendor self service
# 3                                             Pay $25                  NaN
# 4                                          BID0053216           jeffgrover
# 5                                    VS50000000026537           jeffgrover
# 6                                                 NaN           jeffgrover
# 7                                                 NaN           jeffgrover
# 8                                          7263982948              FLGGI33
# 9   http://doas.ga.gov/state-purchasing/statewide-...  vendor self service
# 10                                                NaN           jeffgrover
# 11                                   Need to get code   ggi.vssr@gmail.com
# 12                                                NaN             Must pay
# 13                                                NaN   ggi.vssr@gmail.com
# 14                                        VS000003477           jeffgrover
# 15                                                NaN                  NaN
# 16                                                NaN           jeffgrover
# 17                                                NaN  vendor self service
# 18                                                NaN                  NaN
# 19                                           00040260           jeffgrover
# 20                                                NaN  vendor self service
# 21                                           VGGI2017                  NaN
# 22                                         0000123456       VN0000983104_1
# 23  http://www.dfa.ms.gov/dfa-offices/mmrs/mmrs-cu...  vendor self service
# 24                                                NaN  vendor self service
# 25                                                NaN  vendor self service
# 26                                                NaN  vendor self service
# 27                                         8272431081           jeffgrover
# 28                                         I have I-9  vendor self service
# 29                                                NaN  vendor self service
# 30                                                NaN  vendor self service
# 31                                                NaN  vendor self service
# 32                                                NaN  vendor self service
# 33                                                NaN  vendor self service
# 34                                                NaN  vendor self service
# 35                                                NaN  vendor self service
# 36                                                NaN  vendor self service
# 37                                         0000802894  vendor self service
# 38                                                NaN  vendor self service
# 39                                                NaN  vendor self service
# 40                                                NaN  vendor self service
# 41                                                NaN  vendor self service
# 42                                                NaN  vendor self service
# 43                                                NaN  vendor self service
# 44                                                NaN  vendor self service
# 45                                                NaN  vendor self service
# 46                                                NaN  vendor self service
# 47                                                NaN  vendor self service
# 48                                                NaN  vendor self service
# 49  https://www.publicpurchase.com/gems/login/logi...  vendor self service
#
#                                                    pw  \
# 0                                            Eyeman59
# 1                                           Eyeman59%
# 2                                                 NaN
# 3                                                 NaN
# 4                                           Eyeman59%
# 5                                           Eyeman59%
# 6                                            Eyeman59
# 7                                          Eyeman1957
# 8                                           Eyeman59!
# 9                                                 NaN
# 10                                           Eyeman59
# 11                                          Eyeman59%
# 12                                                NaN
# 13                                          Eyeman59%
# 14                                                NaN
# 15                                                NaN
# 16                                           Eyeman59
# 17                                                NaN
# 18                                                NaN
# 19                                          Eyeman59%
# 20                                                NaN
# 21                            Waiting for reset email
# 22                                          Eyeman59%
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                          Eyeman59%
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37  https://www.myworkplace.state.pa.us:448/sap/bc...
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                          supplier_url  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10  https://vendors.ehawaii.gov/hce/splash/welcome...
# 11                                                NaN
# 12                                                NaN
# 13                    Need to hire a registered agent
# 14  need to update email from drjeffgrover@thedata...
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21  http://www.michigan.gov/mdot/0,4616,7-151-9625...
# 22                  http://supplier.swift.state.mn.us
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                                      url_registration  \
# 0   https://procurement.staars.alabama.gov/webapp/...
# 1   https://iris-vss.alaska.gov/webapp/PRDVSS1X1/A...
# 2                                                 NaN
# 3               https://www.ark.org/vendor/vendor.php
# 4     https://www.caleprocure.ca.gov/pages/index.aspx
# 5   https://codpa-vss.hostams.com/webapp/PRDVSS1X1...
# 6             http://www.osc.ct.gov/vendor/index.html
# 7   http://mymarketplace.delaware.gov/vendor-regis...
# 8   https://vendor.myfloridamarketplace.com/vms-we...
# 9       http://doas.ga.gov/state-purchasing/suppliers
# 10            https://hiepro.ehawaii.gov/welcome.html
# 11    https://purchasing.idaho.gov/iprovendorreg.html
# 12                              http://www.ilsos.net/
# 13                    http://www.in.gov/idoa/2355.htm
# 14  https://vss.iowa.gov/webapp/VSS_ON/AltSelfService
# 15                                                NaN
# 16  https://emars.ky.gov/webapp/vssonline/AltSelfS...
# 17  https://lagoverpvendor.doa.louisiana.gov/irj/p...
# 18  https://mevss.hostams.com/webapp/PRDVSS2X1/Alt...
# 19                https://emaryland.buyspeed.com/bso/
# 20                                                NaN
# 21  http://www.michigan.gov/budget/0,4538,7-157-79...
# 22           http://www.mmd.admin.state.mn.us/webven/
# 23  https://sus.magic.ms.gov/sap/bc/webdynpro/saps...
# 24                                https://ess.mo.gov/
# 25                     http://vendorresources.mt.gov/
# 26                                                NaN
# 27                      http://vms.purchasing.nv.gov/
# 28  https://das.nh.gov/purchasing/vendorregistrati...
# 29          http://www.nj.gov/njbusiness/contracting/
# 30  https://solutions.sciquest.com/apps/Router/Sup...
# 31  http://www.osc.state.ny.us/vendors/vendorselfs...
# 32             http://eprocurement.nc.gov/Vendor.html
# 33                 http://sos.nd.gov/business/vendors
# 34                      http://supplier.obm.ohio.gov/
# 35          https://pay.apps.ok.gov/dcs/vendors2/app/
# 36  http://fa.oregonstate.edu/business-affairs/new...
# 37  http://www.dgs.pa.gov/Businesses/Small%20Busin...
# 38  http://www.purchasing.ri.gov/vendors/vendorinf...
# 39     https://procurement.sc.gov/vendor/registration
# 40  https://boa.sd.gov/divisions/procurement/vendors/
# 41  https://www.tn.gov/generalservices/topic/vendo...
# 42  https://comptroller.texas.gov/purchasing/vendo...
# 43  http://solutions.sciquest.com/apps/Router/Supp...
# 44                                                NaN
# 45  https://vendor.epro.cgipdc.com/loginEngine/ind...
# 46  http://www.des.wa.gov/services/contracting-pur...
# 47  https://prod-fin-vss.wvoasis.gov/webapp/prdvss...
# 48         https://vendornet.wi.gov/Registration.aspx
# 49  https://www.publicpurchase.com/gems/register/v...
#
#                                                Notes1  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                              SDVOSB
# 5                                                 NaN
# 6                         Waiting on validation email
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                 ggi.vssr@gmail.com
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37     https://www.login.state.pa.us/login/Login.aspx
# 38  Please fill out the attached RIFANS Registrati...
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                           Waiting to become active
#
#                                                Notes2  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   https://www.dgs.ca.gov/pd/Programs/caleprocure...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN
#
#                          Notes3  \
# 0                           NaN
# 1                           NaN
# 2                           NaN
# 3                           NaN
# 4   Need to registor here also:
# 5                           NaN
# 6                           NaN
# 7                           NaN
# 8                           NaN
# 9                           NaN
# 10                          NaN
# 11                          NaN
# 12                          NaN
# 13                          NaN
# 14                          NaN
# 15                          NaN
# 16                          NaN
# 17                          NaN
# 18                          NaN
# 19                          NaN
# 20                          NaN
# 21                          NaN
# 22                          NaN
# 23                          NaN
# 24                          NaN
# 25                          NaN
# 26                          NaN
# 27                          NaN
# 28                          NaN
# 29                          NaN
# 30                          NaN
# 31                          NaN
# 32                          NaN
# 33                          NaN
# 34                          NaN
# 35                          NaN
# 36                          NaN
# 37                       802894
# 38                          NaN
# 39                          NaN
# 40                          NaN
# 41                          NaN
# 42                          NaN
# 43                          NaN
# 44                          NaN
# 45                          NaN
# 46                          NaN
# 47                          NaN
# 48                          NaN
# 49                          NaN
#
#                                           Unnamed: 11
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   https://www.caleprocure.ca.gov/pages/SupplierR...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32                                                NaN
# 33                                                NaN
# 34                                                NaN
# 35                                                NaN
# 36                                                NaN
# 37                                                NaN
# 38                                                NaN
# 39                                                NaN
# 40                                                NaN
# 41                                                NaN
# 42                                                NaN
# 43                                                NaN
# 44                                                NaN
# 45                                                NaN
# 46                                                NaN
# 47                                                NaN
# 48                                                NaN
# 49                                                NaN

# %%
##############################################################################
#
# A simple example of converting a Pandas dataframe to an xlsx file using
# Pandas and XlsxWriter.
#
# Copyright 2013-2017, John McNamara, jmcnamara@cpan.org
#

import pandas as pd


# Create a Pandas dataframe from some data.
df = pd.DataFrame({'Data': [10, 20, 30, 20, 15, 30, 45]})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter('pandas_simple.xlsx', engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
df
# Out:
#    Data
# 0    10
# 1    20
# 2    30
# 3    20
# 4    15
# 5    30
# 6    45

# %%
##############################################################################
#
# An example of converting a Pandas dataframe to an xlsx file
# with column formats using Pandas and XlsxWriter.
#
# Copyright 2013-2017, John McNamara, jmcnamara@cpan.org
#

import pandas as pd

# Create a Pandas dataframe from some data.
df = pd.DataFrame({'Numbers':    [1010, 2020, 3030, 2020, 1515, 3030, 4545],
                   'Percentage': [.1,   .2,   .33,  .25,  .5,   .75,  .45 ],
})

# Create a Pandas Excel writer using XlsxWriter as the engine.
writer = pd.ExcelWriter("pandas_column_formats.xlsx", engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object.
df.to_excel(writer, sheet_name='Sheet1')

# Get the xlsxwriter workbook and worksheet objects.
workbook  = writer.book
worksheet = writer.sheets['Sheet1']

# Add some cell formats.
format1 = workbook.add_format({'num_format': '#,##0.00'})
format2 = workbook.add_format({'num_format': '0%'})

# Note: It isn't possible to format any cells that already have a format such
# as the index or headers or any cells that contain dates or datetimes.

# Set the column width and format.
worksheet.set_column('B:B', 18, format1)

# Set the format but not the column width.
worksheet.set_column('C:C', None, format2)

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %%
df
# Out:
#    Numbers  Percentage
# 0     1010        0.10
# 1     2020        0.20
# 2     3030        0.33
# 3     2020        0.25
# 4     1515        0.50
# 5     3030        0.75
# 6     4545        0.45
