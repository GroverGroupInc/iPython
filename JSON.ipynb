# %%
import pandas as pd

# %%
#https://catalog.data.gov/dataset
#https://help.parsehub.com/hc/en-us/articles/219619888-Analyzing-JSON-With-Python
df = pd.read_json("http://data.consumerfinance.gov/api/views.json")

# %%
df
# Out:
#     averageRating    category   createdAt  \
# 0             100         NaN  1431450318
# 1               0         NaN  1434123722
# 2               0  Government  1347900842
# 3               0  Government  1350323610
# 4               0         NaN  1433952949
# 5               0         NaN  1434384894
# 6               0         NaN  1434384833
# 7               0         NaN  1434038104
# 8               0         NaN  1434384651
# 9               0         NaN  1434384321
# 10              0         NaN  1434385637
# 11              0         NaN  1434385479
# 12              0         NaN  1434385340
# 13              0         NaN  1434385239
# 14              0         NaN  1434039416
# 15              0         NaN  1434385090
# 16              0         NaN  1434039311
# 17              0         NaN  1434385198
# 18              0         NaN  1434471578
# 19              0         NaN  1434467591
# 20              0         NaN  1462304711
# ...

# %%
df = pd.crosstab([df.averageRating], df.category, margins=True)

# %%
df
# Out:
# category       Government  All
# averageRating
# 0                       2    2
# All                     2    2

# %% [markdown]
# ## API: https://www.dataquest.io/blog/python-api-tutorial/

# %%
import requests
response = requests.get("http://api.open-notify.org/iss-now.json")

# %%
response.status_code
# Out:
# 200

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74")

# %%
parameters = {"lat": 40.71, "lon": -74}

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1492025473, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 562, \n      "risetime": 1492036804\n    }, \n    {\n      "duration": 632, \n      "risetime": 1492042589\n    }, \n    {\n      "duration": 574, \n      "risetime": 1492048387\n    }, \n    {\n      "duration": 558, \n      "risetime": 1492102557\n    }\n  ]\n}\n'

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json?lat=40.71&lon=-74")

# %%
response.content
# Out:
# b'{\n  "message": "success", \n  "request": {\n    "altitude": 100, \n    "datetime": 1492025473, \n    "latitude": 40.71, \n    "longitude": -74.0, \n    "passes": 5\n  }, \n  "response": [\n    {\n      "duration": 562, \n      "risetime": 1492036804\n    }, \n    {\n      "duration": 632, \n      "risetime": 1492042589\n    }, \n    {\n      "duration": 574, \n      "risetime": 1492048387\n    }, \n    {\n      "duration": 558, \n      "risetime": 1492102557\n    }\n  ]\n}\n'

# %% [markdown]
# ## More...

# %%
best_food_chains = ["Taco Bell", "Shake Shack", "Chipotle"]

# %%
type(best_food_chains)
# Out:
# list

# %%
import json

# %%
best_food_chains_string = json.dumps(best_food_chains)

# %%
type(best_food_chains_string)
# Out:
# str

# %%
type(json.loads(best_food_chains_string))
# Out:
# list

# %%
fast_food_franchise = {
    "Subway": 24722,
    "McDonalds": 14098,
    "Starbucks": 10821,
    "Pizza Hut": 7600
}

# %%
fast_food_franchise_string = json.dumps(fast_food_franchise)
type(fast_food_franchise_string)
# Out:
# str

# %% [markdown]
# ##Getting JSON from an API request

# %%
parameters = {"lat": 37.78, "lon": -122.41}

# %%
response = requests.get("http://api.open-notify.org/iss-pass.json", params=parameters)

# %%
data = response.json()
type(data)
data
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1492025706,
#   'latitude': 37.78,
#   'longitude': -122.41,
#   'passes': 5},
#  'response': [{'duration': 619, 'risetime': 1492030374},
#   {'duration': 596, 'risetime': 1492036176},
#   {'duration': 481, 'risetime': 1492042076},
#   {'duration': 495, 'risetime': 1492047934},
#   {'duration': 611, 'risetime': 1492053712}]}

# %%
{'response': [{'risetime': 1441456672, 'duration': 369}, {'risetime': 1441462284, 'duration': 626}, {'risetime': 1441468104, 'duration': 581}, {'risetime': 1441474000, 'duration': 482}, {'risetime': 1441479853, 'duration': 509}], 'message': 'success', 'request': {'latitude': 37.78, 'passes': 5, 'longitude': -122.41, 'altitude': 100, 'datetime': 1441417753}}
# Out:
# {'message': 'success',
#  'request': {'altitude': 100,
#   'datetime': 1441417753,
#   'latitude': 37.78,
#   'longitude': -122.41,
#   'passes': 5},
#  'response': [{'duration': 369, 'risetime': 1441456672},
#   {'duration': 626, 'risetime': 1441462284},
#   {'duration': 581, 'risetime': 1441468104},
#   {'duration': 482, 'risetime': 1441474000},
#   {'duration': 509, 'risetime': 1441479853}]}

# %%
# Headers is a dictionary
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Type': 'application/json', 'Via': '1.1 vegur', 'Server': 'nginx/1.6.2', 'Content-Length': '521', 'Date': 'Wed, 12 Apr 2017 19:35:06 GMT'}

# %%
# Get the content-type from the dictionary.
response.headers["content-type"]
# Out:
# 'application/json'

# %% [markdown]
# ##Finding the number of people in space

# %%
# Get the response from the API endpoint.
response = requests.get("http://api.open-notify.org/astros.json")
data = response.json()

# %%
# 9 people are currently in space.
data["number"]
# Out:
# 3

# %%
{'number': 9, 'people': [{'name': 'Gennady Padalka', 'craft': 'ISS'}, {'name': 'Mikhail Kornienko', 'craft': 'ISS'}, {'name': 'Scott Kelly', 'craft': 'ISS'}, {'name': 'Oleg Kononenko', 'craft': 'ISS'}, {'name': 'Kimiya Yui', 'craft': 'ISS'}, {'name': 'Kjell Lindgren', 'craft': 'ISS'}, {'name': 'Sergey Volkov', 'craft': 'ISS'}, {'name': 'Andreas Mogensen', 'craft': 'ISS'}, {'name': 'Aidyn Aimbetov', 'craft': 'ISS'}], 'message': 'success'}
# Out:
# {'message': 'success',
#  'number': 9,
#  'people': [{'craft': 'ISS', 'name': 'Gennady Padalka'},
#   {'craft': 'ISS', 'name': 'Mikhail Kornienko'},
#   {'craft': 'ISS', 'name': 'Scott Kelly'},
#   {'craft': 'ISS', 'name': 'Oleg Kononenko'},
#   {'craft': 'ISS', 'name': 'Kimiya Yui'},
#   {'craft': 'ISS', 'name': 'Kjell Lindgren'},
#   {'craft': 'ISS', 'name': 'Sergey Volkov'},
#   {'craft': 'ISS', 'name': 'Andreas Mogensen'},
#   {'craft': 'ISS', 'name': 'Aidyn Aimbetov'}]}

# %% [markdown]
# ##Python API tutorial: Next steps

# %%
import requests

# %%
response = requests.get("http://api.open-notify.org/iss-now.json")
response.status_code
# Out:
# 200

# %%
response = requests.get("http://data.consumerfinance.gov/api/views/s6ew-h6mp.json")

# %%
data = response.json()

# %%
data
# Out:
# {'averageRating': 100,
#  'columns': [{'cachedContents': {'largest': '2017-04-10T21:25:43',
#     'non_null': 754192,
#     'null': 0,
#     'smallest': '2011-12-01T05:27:56',
#     'top': [{'count': 20, 'item': '2017-03-13T15:50:59'},
#      {'count': 19, 'item': '2017-01-20T14:36:13'},
#      {'count': 18, 'item': '2017-04-05T19:03:36'},
#      {'count': 17, 'item': '2017-02-10T00:36:32'},
#      {'count': 16, 'item': '2017-04-03T13:41:56'},
#      {'count': 15, 'item': '2017-04-04T12:59:09'},
#      {'count': 14, 'item': '2017-02-09T23:20:51'},
#      {'count': 13, 'item': '2017-03-29T17:01:21'},
#      {'count': 12, 'item': '2017-04-07T00:44:52'},
#      {'count': 11, 'item': '2017-04-10T18:38:02'},
#      {'count': 10, 'item': '2017-03-29T16:14:32'},
#      {'count': 9, 'item': '2017-02-09T20:38:17'},
#      {'count': 8, 'item': '2017-02-24T18:26:25'},
#      {'count': 7, 'item': '2017-04-08T20:45:57'},
#      {'count': 6, 'item': '2017-01-27T02:16:54'},
# ...

# %%
response = requests.get("https://gis.ers.usda.gov/arcgis/rest/services/")

# %%
response = requests.get("http://catalog.data.gov/api/3/")

# %%
response
# Out:
# <Response [200]>

# %%
data = response.json()

# %%
data
# Out:
# {'version': 3}

# %% [markdown]
# ##Treasury data

# %%
pd.read_json
# Out:
# <function pandas.io.json.read_json>

# %%
df = pd.read_json("https://www.opendata.go.ke/resource/p452-xb7c.json")
# Out:
# ---------------------------------------------------------------------------
# CertificateError                          Traceback (most recent call last)
# <ipython-input-89-f98a60345db5> in <module>()
# ----> 1 df = pd.read_json("https://www.opendata.go.ke/resource/p452-xb7c.json")
#
# C:\Users\Valued Customer\Anaconda3\lib\site-packages\pandas\io\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit)
#     185     """
#     186
# --> 187     filepath_or_buffer, _, _ = get_filepath_or_buffer(path_or_buf)
#     188     if isinstance(filepath_or_buffer, compat.string_types):
#     189         try:
#
# C:\Users\Valued Customer\Anaconda3\lib\site-packages\pandas\io\common.py in get_filepath_or_buffer(filepath_or_buffer, encoding, compression)
#     306
#     307     if _is_url(filepath_or_buffer):
# --> 308         req = _urlopen(str(filepath_or_buffer))
#     309         if compression == 'infer':
# ...
